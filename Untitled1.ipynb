# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharuk-baba/Research/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy scipy matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import svd

# Define a simple nonlinear system
def f(x):
    return x**2 - 0.5  # Example nonlinear function

# Generate data
x_values = np.linspace(-1, 1, 100)  # Input values
y_values = f(x_values)  # Apply the function

# Plot the function
plt.plot(x_values, y_values, label="f(x) = x^2 - 0.5")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid()
plt.show()

# %%
# Compute Koopman approximation using Least Squares
K = np.linalg.lstsq(X.T, Y.T, rcond=None)[0]  # K has shape (99,1)

# Predict using the Koopman operator
Y_pred = (K.T @ X).flatten()  # Fix matrix multiplication issue

# Plot results
plt.plot(x_values[:-1], Y.flatten(), label="True f(x)")
plt.plot(x_values[:-1], Y_pred, '--', label="Koopman Approximation")
plt.xlabel("x")
plt.ylabel("Value")
plt.legend()
plt.grid()
plt.show()
